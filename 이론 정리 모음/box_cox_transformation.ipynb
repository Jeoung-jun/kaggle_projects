# %%
import numpy as np
from scipy.special import boxcox1p, boxcox
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

x =np.random.exponential(size = 1000)
lambda_select = 0.3
y= boxcox1p(x-1, lambda_select)
print(lambda_select)
# Out:
# 0.3

# %%
sns.distplot(x, hist=True, kde=True, color='blue')
# Out:
# /Users/austin/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
# 람다 값을 계속 변화시키면서 정규분포에 가깝게 만들어주는 것이 필요하다. 
sns.distplot(y, hist=True, kde=True, color='red')
# Out:
# /Users/austin/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>
